# %%
import pandas as pd
from config import gkey
import requests
from pprint import pprint

# %%
zillow = pd.read_csv("Zillow_Metro.csv")
# Out:
#      RegionID  SizeRank                          RegionName RegionType  \
# 0      102001         0                       United States    Country
# 1      394913         1                        New York, NY        Msa
# 2      753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3      394463         3                         Chicago, IL        Msa
# 4      394514         4               Dallas-Fort Worth, TX        Msa
# ..        ...       ...                                 ...        ...
# 882    753927       924                      Winnemucca, NV        Msa
# 883    395142       925                      Sweetwater, TX        Msa
# 884    395186       928                      Vermillion, SD        Msa
# 885    753874       930                           Craig, CO        Msa
# 886    394743       933                       Ketchikan, AK        Msa
#
#     StateName  1/31/1996  2/29/1996  3/31/1996  4/30/1996  5/31/1996  ...  \
# 0         NaN    71446.0    71447.0    71454.0    71503.0    71554.0  ...
# 1          NY   141156.0   140959.0   140795.0   140551.0   140316.0  ...
# 2          CA   111822.0   111897.0   111856.0   111803.0   111695.0  ...
# 3          IL   100693.0   100488.0   100225.0   100026.0    99682.0  ...
# 4          TX    72320.0    71927.0    71880.0    72243.0    72596.0  ...
# ..        ...        ...        ...        ...        ...        ...  ...
# 882        NV        NaN        NaN        NaN        NaN        NaN  ...
# 883        TX        NaN        NaN        NaN        NaN        NaN  ...
# 884        SD        NaN        NaN        NaN        NaN        NaN  ...
# 885        CO        NaN        NaN        NaN        NaN        NaN  ...
# 886        AK        NaN        NaN        NaN        NaN        NaN  ...
#
#      8/31/2019  9/30/2019  10/31/2019  11/30/2019  12/31/2019  1/31/2020  \
# 0       181070     181601      182145      182673      183220     183831
# 1       409424     409500      409332      409004      409178     409191
# 2       441012     442629      444001      444895      446340     448009
# 3       170042     170131      170199      170190      170167     170346
# 4       136286     137952      138454      138840      137942     137709
# ..         ...        ...         ...         ...         ...        ...
# 882     131624     131244      130841      129855      128791     127948
# 883      66792      67256       67941       68692       68847      68861
# 884      89033      89529       89866       90285       90871      91417
# 885      91229      91046       90596       90033       89607      89539
# 886      79787      80032       80346       80497       80597      80635
#
#      2/29/2020  3/31/2020  4/30/2020  5/31/2020
# 0       184509     185184     185803     186273
# 1       409330     408959     408789     408325
# 2       450577     452598     453809     453018
# 3       170680     171020     171088     170954
# 4       137458     137785     138435     139288
# ..         ...        ...        ...        ...
# 882     127555     126969     126778     126481
# 883      68623      68286      67272      66077
# 884      92160      92678      93332      93398
# 885      89376      89059      89213      89744
# 886      80694      80727      80697      80789
#
# [887 rows x 298 columns]

# %%
zillow["Name"] = ""
zillow["lat"] = ""
zillow["lng"] = ""

params = {"key": gkey}

counter = 0
for index, row in zillow.iterrows():
    base_url = "https://maps.googleapis.com/maps/api/geocode/json?"

    this = row["RegionName"]
    params["address"] = this
    
    query = requests.get(base_url, params=params)
    data = query.json()
    
    try:
        lat = data["results"][0]["geometry"]["location"]["lat"]
        lng = data["results"][0]["geometry"]["location"]["lng"]
        
        zillow.loc[index, "lat"] = lat
        zillow.loc[index, "lng"] = lng

    except:
        print("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!Character not found")
        pass
    
    counter = counter + 1
  
    print(lat, lng, counter)
    
zillow
    
    
zillow.to_csv("zillow_w_lat_lng")
# Out:
# 37.09024 -95.712891 1
# 40.7127753 -74.0059728 2
# 34.0522166 -118.2436619 3
# 41.8781136 -87.6297982 4
# 32.7078751 -96.9209135 5
# 39.9525839 -75.1652215 6
# 29.7604267 -95.3698028 7
# 38.9071923 -77.0368707 8
# 26.0742344 -80.1506022 9
# 33.7489954 -84.3879824 10
# 42.3600825 -71.0588801 11
# 37.7749295 -122.4194155 12
# 42.331427 -83.0457538 13
# 33.9806005 -117.3754942 14
# 33.4483771 -112.0740373 15
# 47.6062095 -122.3320708 16
# 44.9374831 -93.20099979999999 17
# 32.715738 -117.1610838 18
# 38.6270025 -90.19940419999999 19
# 27.950575 -82.4571776 20
# 39.2903848 -76.6121893 21
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-a44d43f67af6> in <module>
#      14     #params['components'] = f'administrative_area_level_1: OH'
#      15     params["address"] = this
# ---> 16     query = requests.get(base_url, params=params)
#      17
#      18     data = query.json()
#
# ~/anaconda3/envs/hunter/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/anaconda3/envs/hunter/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/anaconda3/envs/hunter/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~/anaconda3/envs/hunter/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/envs/hunter/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/anaconda3/envs/hunter/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     670                 body=body,
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#     674
#
# ~/anaconda3/envs/hunter/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     374         # Trigger any extra validation we need to do.
#     375         try:
# --> 376             self._validate_conn(conn)
#     377         except (SocketTimeout, BaseSSLError) as e:
#     378             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/anaconda3/envs/hunter/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     992         # Force connect early to allow us to validate the connection.
#     993         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 994             conn.connect()
#     995
#     996         if not conn.is_verified:
#
# ~/anaconda3/envs/hunter/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     358             ca_cert_dir=self.ca_cert_dir,
#     359             server_hostname=server_hostname,
# --> 360             ssl_context=context,
#     361         )
#     362
#
# ~/anaconda3/envs/hunter/lib/python3.7/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password)
#     368     ) or IS_SECURETRANSPORT:
#     369         if HAS_SNI and server_hostname is not None:
# --> 370             return context.wrap_socket(sock, server_hostname=server_hostname)
#     371
#     372         warnings.warn(
#
# ~/anaconda3/envs/hunter/lib/python3.7/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     421             server_hostname=server_hostname,
#     422             context=self,
# --> 423             session=session
#     424         )
#     425
#
# ~/anaconda3/envs/hunter/lib/python3.7/ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#     868                         # non-blocking
#     869                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 870                     self.do_handshake()
#     871             except (OSError, ValueError):
#     872                 self.close()
#
# ~/anaconda3/envs/hunter/lib/python3.7/ssl.py in do_handshake(self, block)
#    1137             if timeout == 0.0 and block:
#    1138                 self.settimeout(None)
# -> 1139             self._sslobj.do_handshake()
#    1140         finally:
#    1141             self.settimeout(timeout)
#
# KeyboardInterrupt:
